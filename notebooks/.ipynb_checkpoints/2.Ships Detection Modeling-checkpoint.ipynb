# %% [markdown]
# # <center> Modeling

# %% [markdown]
# In this notebook, we will implement our models, choose metrics, train the models, test them and select the best one

# %% [markdown]
# # Import

# %%
import json
import numpy as np
import pandas as pd

import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical #if error replace "to_categorical" to "np_utils"
from tensorflow.python.keras.metrics import Metric
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, AveragePooling2D,Flatten,
                                    Dense, Dropout, Activation)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
mpl.rcParams['figure.figsize'] = (12, 10)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Data must be formatted before being fed into NN :
# 1. First, we need to reshape the data, specifiying the size and number of color channels
# 2. Secondly, we need to convert them into floating point tensors
# 2. Then, rescale the tensors to values between 0 and 1, as neural networks prefer to deal with small input values.

# %%
with open(r'../data/shipsnet.json') as f:
    dataset = json.load(f)

X = np.array(dataset['data']).astype('uint8')
y = np.array(dataset['labels']).astype('uint8')

# %%
X = X.reshape([-1, 3, 80, 80]).transpose([0,2,3,1])
X = X / 255
print(X.shape)

y = to_categorical(y, 2)
# Out:
# (4000, 80, 80, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                  test_size=0.25,
                                                  random_state=42)

# %%
print(np.shape(X_train))
print(np.shape(X_val))
print(np.shape(X_test))
print("###############")
print(np.shape(y_train))
print(np.shape(y_val))
print(np.shape(y_test))
# Out:
# (2400, 80, 80, 3)
# (800, 80, 80, 3)
# (800, 80, 80, 3)
# ###############
# (2400, 2)
# (800, 2)
# (800, 2)

# %% [markdown]
# # Metrics

# %% [markdown]
# Here are some first-order suggestions:
#
#      1-Are you predicting probabilities?
#         2-Do you need class labels?
#             3-Is the positive class more important?
#                 A=>-Use Precision-Recall AUC
#             3-Are both classes important?
#                 A=>-Use ROC AUC
#         2-Do you need probabilities?
#             3-Use Brier Score and Brier Skill Score

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %% [markdown]
# # Setting model parameters

# %% [markdown]
# We will use Vincent's Vanhoucke “stretch pants” approach: instead of wasting time looking for the perfect model that perfectly match the problematic, we will just use large parameters that will shrink down to the right size.

# %%
EPOCHS = 100

# %% [markdown]
# As we use this approach. We have to put mechanisms which will prevent our model from overfitting.
#
# This callback will stop the training when there is no improvement in the loss for 10 consecutive epochs.

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ### Set the correct intial bias

# %% [markdown]
# We know the dataset is imbalanced. We need to set the output layer's bias to reflect that. This can help with initial convergence.

# %% [markdown]
# * ##### Without

# %%
output_bias=None
model = Sequential()
model.add(Flatten(input_shape=[80, 80, 3]))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax',
               bias_initializer=output_bias)) #For a better interpretability

model.compile(loss='categorical_crossentropy', optimizer='Adam')

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print("Loss: {:0.4f}".format(results))
# Out:
# Loss: 1.4514

# %% [markdown]
# * ##### With bias initialization

# %%
neg, pos = 3000, 1000
initial_bias = np.log([pos/neg])

output_bias = tf.keras.initializers.Constant(initial_bias)

# %%
model = Sequential()
model.add(Flatten(input_shape=[80, 80, 3]))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax',
               bias_initializer=output_bias)) #For a better interpretability

model.compile(loss='categorical_crossentropy', optimizer='Adam')
              #metrics=METRICS)

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print("Loss: {:0.4f}".format(results))
# Out:
# Loss: 0.6934

# %% [markdown]
# The initial loss is about 2 times less than it would have been with naive initialization. with this our model will converge much faster

# %% [markdown]
# # Train the model

# %% [markdown]
# ## Fully conncted

# %%
model = Sequential()
model.add(Flatten(input_shape=[80, 80, 3]))
model.add(Dense(200, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax',
               bias_initializer=output_bias)) #For a better interpretability

model.compile(loss='categorical_crossentropy', optimizer='Adam',metrics=METRICS)

# %%
history = model.fit(X_train, y_train,
                    epochs=EPOCHS,
                    callbacks=[early_stopping],
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 22s 57ms/step - loss: 0.5412 - tp: 1812.0000 - fp: 588.0000 - tn: 1812.0000 - fn: 588.0000 - accuracy: 0.7550 - precision: 0.7550 - recall: 0.7550 - auc: 0.8004 - prc: 0.7845 - val_loss: 0.4539 - val_tp: 628.0000 - val_fp: 172.0000 - val_tn: 628.0000 - val_fn: 172.0000 - val_accuracy: 0.7850 - val_precision: 0.7850 - val_recall: 0.7850 - val_auc: 0.8779 - val_prc: 0.8799
# Epoch 2/100
# 75/75 [==============================] - 2s 28ms/step - loss: 0.3985 - tp: 1998.0000 - fp: 402.0000 - tn: 1998.0000 - fn: 402.0000 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9008 - prc: 0.8984 - val_loss: 0.4277 - val_tp: 658.0000 - val_fp: 142.0000 - val_tn: 658.0000 - val_fn: 142.0000 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9115 - val_prc: 0.9137
# Epoch 3/100
# 75/75 [==============================] - 2s 27ms/step - loss: 0.3180 - tp: 2066.0000 - fp: 334.0000 - tn: 2066.0000 - fn: 334.0000 - accuracy: 0.8608 - precision: 0.8608 - recall: 0.8608 - auc: 0.9383 - prc: 0.9382 - val_loss: 0.2811 - val_tp: 706.0000 - val_fp: 94.0000 - val_tn: 706.0000 - val_fn: 94.0000 - val_accuracy: 0.8825 - val_precision: 0.8825 - val_recall: 0.8825 - val_auc: 0.9564 - val_prc: 0.9578
# Epoch 4/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.2764 - tp: 2114.0000 - fp: 286.0000 - tn: 2114.0000 - fn: 286.0000 - accuracy: 0.8808 - precision: 0.8808 - recall: 0.8808 - auc: 0.9535 - prc: 0.9539 - val_loss: 0.2490 - val_tp: 716.0000 - val_fp: 84.0000 - val_tn: 716.0000 - val_fn: 84.0000 - val_accuracy: 0.8950 - val_precision: 0.8950 - val_recall: 0.8950 - val_auc: 0.9627 - val_prc: 0.9636
# Epoch 5/100
# 75/75 [==============================] - 2s 27ms/step - loss: 0.2928 - tp: 2090.0000 - fp: 310.0000 - tn: 2090.0000 - fn: 310.0000 - accuracy: 0.8708 - precision: 0.8708 - recall: 0.8708 - auc: 0.9475 - prc: 0.9473 - val_loss: 0.3052 - val_tp: 698.0000 - val_fp: 102.0000 - val_tn: 698.0000 - val_fn: 102.0000 - val_accuracy: 0.8725 - val_precision: 0.8725 - val_recall: 0.8725 - val_auc: 0.9444 - val_prc: 0.9436
# Epoch 6/100
# 75/75 [==============================] - 2s 27ms/step - loss: 0.2547 - tp: 2143.0000 - fp: 257.0000 - tn: 2143.0000 - fn: 257.0000 - accuracy: 0.8929 - precision: 0.8929 - recall: 0.8929 - auc: 0.9603 - prc: 0.9611 - val_loss: 0.2968 - val_tp: 714.0000 - val_fp: 86.0000 - val_tn: 714.0000 - val_fn: 86.0000 - val_accuracy: 0.8925 - val_precision: 0.8925 - val_recall: 0.8925 - val_auc: 0.9510 - val_prc: 0.9502
# Epoch 7/100
# 75/75 [==============================] - 2s 27ms/step - loss: 0.2297 - tp: 2168.0000 - fp: 232.0000 - tn: 2168.0000 - fn: 232.0000 - accuracy: 0.9033 - precision: 0.9033 - recall: 0.9033 - auc: 0.9682 - prc: 0.9690 - val_loss: 0.2373 - val_tp: 727.0000 - val_fp: 73.0000 - val_tn: 727.0000 - val_fn: 73.0000 - val_accuracy: 0.9087 - val_precision: 0.9087 - val_recall: 0.9087 - val_auc: 0.9685 - val_prc: 0.9697
# Epoch 8/100
# 75/75 [==============================] - 2s 27ms/step - loss: 0.2494 - tp: 2147.0000 - fp: 253.0000 - tn: 2147.0000 - fn: 253.0000 - accuracy: 0.8946 - precision: 0.8946 - recall: 0.8946 - auc: 0.9619 - prc: 0.9623 - val_loss: 0.2016 - val_tp: 736.0000 - val_fp: 64.0000 - val_tn: 736.0000 - val_fn: 64.0000 - val_accuracy: 0.9200 - val_precision: 0.9200 - val_recall: 0.9200 - val_auc: 0.9767 - val_prc: 0.9776
# Epoch 9/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1968 - tp: 2202.0000 - fp: 198.0000 - tn: 2202.0000 - fn: 198.0000 - accuracy: 0.9175 - precision: 0.9175 - recall: 0.9175 - auc: 0.9766 - prc: 0.9773 - val_loss: 0.1881 - val_tp: 744.0000 - val_fp: 56.0000 - val_tn: 744.0000 - val_fn: 56.0000 - val_accuracy: 0.9300 - val_precision: 0.9300 - val_recall: 0.9300 - val_auc: 0.9788 - val_prc: 0.9796
# Epoch 10/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.2025 - tp: 2199.0000 - fp: 201.0000 - tn: 2199.0000 - fn: 201.0000 - accuracy: 0.9162 - precision: 0.9162 - recall: 0.9162 - auc: 0.9751 - prc: 0.9755 - val_loss: 0.2017 - val_tp: 743.0000 - val_fp: 57.0000 - val_tn: 743.0000 - val_fn: 57.0000 - val_accuracy: 0.9287 - val_precision: 0.9287 - val_recall: 0.9287 - val_auc: 0.9773 - val_prc: 0.9777
# Epoch 11/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1752 - tp: 2236.0000 - fp: 164.0000 - tn: 2236.0000 - fn: 164.0000 - accuracy: 0.9317 - precision: 0.9317 - recall: 0.9317 - auc: 0.9814 - prc: 0.9819 - val_loss: 0.1761 - val_tp: 750.0000 - val_fp: 50.0000 - val_tn: 750.0000 - val_fn: 50.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9817 - val_prc: 0.9823
# Epoch 12/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1716 - tp: 2233.0000 - fp: 167.0000 - tn: 2233.0000 - fn: 167.0000 - accuracy: 0.9304 - precision: 0.9304 - recall: 0.9304 - auc: 0.9820 - prc: 0.9825 - val_loss: 0.1696 - val_tp: 754.0000 - val_fp: 46.0000 - val_tn: 754.0000 - val_fn: 46.0000 - val_accuracy: 0.9425 - val_precision: 0.9425 - val_recall: 0.9425 - val_auc: 0.9823 - val_prc: 0.9829
# Epoch 13/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1555 - tp: 2255.0000 - fp: 145.0000 - tn: 2255.0000 - fn: 145.0000 - accuracy: 0.9396 - precision: 0.9396 - recall: 0.9396 - auc: 0.9850 - prc: 0.9854 - val_loss: 0.1714 - val_tp: 755.0000 - val_fp: 45.0000 - val_tn: 755.0000 - val_fn: 45.0000 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9822 - val_prc: 0.9829
# Epoch 14/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.2076 - tp: 2214.0000 - fp: 186.0000 - tn: 2214.0000 - fn: 186.0000 - accuracy: 0.9225 - precision: 0.9225 - recall: 0.9225 - auc: 0.9738 - prc: 0.9730 - val_loss: 0.2486 - val_tp: 706.0000 - val_fp: 94.0000 - val_tn: 706.0000 - val_fn: 94.0000 - val_accuracy: 0.8825 - val_precision: 0.8825 - val_recall: 0.8825 - val_auc: 0.9651 - val_prc: 0.9670
# Epoch 15/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1938 - tp: 2208.0000 - fp: 192.0000 - tn: 2208.0000 - fn: 192.0000 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9781 - prc: 0.9788 - val_loss: 0.1729 - val_tp: 741.0000 - val_fp: 59.0000 - val_tn: 741.0000 - val_fn: 59.0000 - val_accuracy: 0.9262 - val_precision: 0.9262 - val_recall: 0.9262 - val_auc: 0.9817 - val_prc: 0.9821
# Epoch 16/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1586 - tp: 2248.0000 - fp: 152.0000 - tn: 2248.0000 - fn: 152.0000 - accuracy: 0.9367 - precision: 0.9367 - recall: 0.9367 - auc: 0.9844 - prc: 0.9847 - val_loss: 0.2626 - val_tp: 716.0000 - val_fp: 84.0000 - val_tn: 716.0000 - val_fn: 84.0000 - val_accuracy: 0.8950 - val_precision: 0.8950 - val_recall: 0.8950 - val_auc: 0.9593 - val_prc: 0.9596
# Epoch 17/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1495 - tp: 2259.0000 - fp: 141.0000 - tn: 2259.0000 - fn: 141.0000 - accuracy: 0.9413 - precision: 0.9413 - recall: 0.9413 - auc: 0.9866 - prc: 0.9870 - val_loss: 0.1620 - val_tp: 755.0000 - val_fp: 45.0000 - val_tn: 755.0000 - val_fn: 45.0000 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9839 - val_prc: 0.9844
# Epoch 18/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.2069 - tp: 2212.0000 - fp: 188.0000 - tn: 2212.0000 - fn: 188.0000 - accuracy: 0.9217 - precision: 0.9217 - recall: 0.9217 - auc: 0.9735 - prc: 0.9726 - val_loss: 0.2625 - val_tp: 705.0000 - val_fp: 95.0000 - val_tn: 705.0000 - val_fn: 95.0000 - val_accuracy: 0.8813 - val_precision: 0.8813 - val_recall: 0.8813 - val_auc: 0.9647 - val_prc: 0.9664
# Epoch 19/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1621 - tp: 2251.0000 - fp: 149.0000 - tn: 2251.0000 - fn: 149.0000 - accuracy: 0.9379 - precision: 0.9379 - recall: 0.9379 - auc: 0.9836 - prc: 0.9835 - val_loss: 0.1642 - val_tp: 749.0000 - val_fp: 51.0000 - val_tn: 749.0000 - val_fn: 51.0000 - val_accuracy: 0.9362 - val_precision: 0.9362 - val_recall: 0.9362 - val_auc: 0.9838 - val_prc: 0.9843
# Epoch 20/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1581 - tp: 2253.0000 - fp: 147.0000 - tn: 2253.0000 - fn: 147.0000 - accuracy: 0.9388 - precision: 0.9388 - recall: 0.9388 - auc: 0.9845 - prc: 0.9846 - val_loss: 0.1613 - val_tp: 758.0000 - val_fp: 42.0000 - val_tn: 758.0000 - val_fn: 42.0000 - val_accuracy: 0.9475 - val_precision: 0.9475 - val_recall: 0.9475 - val_auc: 0.9837 - val_prc: 0.9842
# Epoch 21/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1447 - tp: 2263.0000 - fp: 137.0000 - tn: 2263.0000 - fn: 137.0000 - accuracy: 0.9429 - precision: 0.9429 - recall: 0.9429 - auc: 0.9873 - prc: 0.9877 - val_loss: 0.1616 - val_tp: 751.0000 - val_fp: 49.0000 - val_tn: 751.0000 - val_fn: 49.0000 - val_accuracy: 0.9388 - val_precision: 0.9388 - val_recall: 0.9388 - val_auc: 0.9846 - val_prc: 0.9851
# Epoch 22/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1185 - tp: 2289.0000 - fp: 111.0000 - tn: 2289.0000 - fn: 111.0000 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9914 - prc: 0.9917 - val_loss: 0.1550 - val_tp: 756.0000 - val_fp: 44.0000 - val_tn: 756.0000 - val_fn: 44.0000 - val_accuracy: 0.9450 - val_precision: 0.9450 - val_recall: 0.9450 - val_auc: 0.9848 - val_prc: 0.9852
# Epoch 23/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1543 - tp: 2247.0000 - fp: 153.0000 - tn: 2247.0000 - fn: 153.0000 - accuracy: 0.9362 - precision: 0.9362 - recall: 0.9362 - auc: 0.9854 - prc: 0.9858 - val_loss: 0.1608 - val_tp: 754.0000 - val_fp: 46.0000 - val_tn: 754.0000 - val_fn: 46.0000 - val_accuracy: 0.9425 - val_precision: 0.9425 - val_recall: 0.9425 - val_auc: 0.9843 - val_prc: 0.9848
# Epoch 24/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1499 - tp: 2255.0000 - fp: 145.0000 - tn: 2255.0000 - fn: 145.0000 - accuracy: 0.9396 - precision: 0.9396 - recall: 0.9396 - auc: 0.9861 - prc: 0.9859 - val_loss: 0.1577 - val_tp: 752.0000 - val_fp: 48.0000 - val_tn: 752.0000 - val_fn: 48.0000 - val_accuracy: 0.9400 - val_precision: 0.9400 - val_recall: 0.9400 - val_auc: 0.9846 - val_prc: 0.9851
# Epoch 25/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1454 - tp: 2269.0000 - fp: 131.0000 - tn: 2269.0000 - fn: 131.0000 - accuracy: 0.9454 - precision: 0.9454 - recall: 0.9454 - auc: 0.9863 - prc: 0.9863 - val_loss: 0.1853 - val_tp: 748.0000 - val_fp: 52.0000 - val_tn: 748.0000 - val_fn: 52.0000 - val_accuracy: 0.9350 - val_precision: 0.9350 - val_recall: 0.9350 - val_auc: 0.9810 - val_prc: 0.9816
# Epoch 26/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1156 - tp: 2290.0000 - fp: 110.0000 - tn: 2290.0000 - fn: 110.0000 - accuracy: 0.9542 - precision: 0.9542 - recall: 0.9542 - auc: 0.9919 - prc: 0.9921 - val_loss: 0.1579 - val_tp: 756.0000 - val_fp: 44.0000 - val_tn: 756.0000 - val_fn: 44.0000 - val_accuracy: 0.9450 - val_precision: 0.9450 - val_recall: 0.9450 - val_auc: 0.9854 - val_prc: 0.9858
# Epoch 27/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1261 - tp: 2275.0000 - fp: 125.0000 - tn: 2275.0000 - fn: 125.0000 - accuracy: 0.9479 - precision: 0.9479 - recall: 0.9479 - auc: 0.9904 - prc: 0.9904 - val_loss: 0.1728 - val_tp: 749.0000 - val_fp: 51.0000 - val_tn: 749.0000 - val_fn: 51.0000 - val_accuracy: 0.9362 - val_precision: 0.9362 - val_recall: 0.9362 - val_auc: 0.9820 - val_prc: 0.9819
# Epoch 28/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1349 - tp: 2281.0000 - fp: 119.0000 - tn: 2281.0000 - fn: 119.0000 - accuracy: 0.9504 - precision: 0.9504 - recall: 0.9504 - auc: 0.9885 - prc: 0.9882 - val_loss: 0.1627 - val_tp: 755.0000 - val_fp: 45.0000 - val_tn: 755.0000 - val_fn: 45.0000 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9831 - val_prc: 0.9831
# Epoch 29/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1184 - tp: 2293.0000 - fp: 107.0000 - tn: 2293.0000 - fn: 107.0000 - accuracy: 0.9554 - precision: 0.9554 - recall: 0.9554 - auc: 0.9916 - prc: 0.9918 - val_loss: 0.1819 - val_tp: 747.0000 - val_fp: 53.0000 - val_tn: 747.0000 - val_fn: 53.0000 - val_accuracy: 0.9337 - val_precision: 0.9337 - val_recall: 0.9337 - val_auc: 0.9793 - val_prc: 0.9796
# Epoch 30/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1165 - tp: 2291.0000 - fp: 109.0000 - tn: 2291.0000 - fn: 109.0000 - accuracy: 0.9546 - precision: 0.9546 - recall: 0.9546 - auc: 0.9911 - prc: 0.9909 - val_loss: 0.1487 - val_tp: 755.0000 - val_fp: 45.0000 - val_tn: 755.0000 - val_fn: 45.0000 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9860 - val_prc: 0.9863
# Epoch 31/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1155 - tp: 2292.0000 - fp: 108.0000 - tn: 2292.0000 - fn: 108.0000 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9917 - prc: 0.9916 - val_loss: 0.1796 - val_tp: 752.0000 - val_fp: 48.0000 - val_tn: 752.0000 - val_fn: 48.0000 - val_accuracy: 0.9400 - val_precision: 0.9400 - val_recall: 0.9400 - val_auc: 0.9793 - val_prc: 0.9786
# Epoch 32/100
# 75/75 [==============================] - 2s 27ms/step - loss: 0.1380 - tp: 2283.0000 - fp: 117.0000 - tn: 2283.0000 - fn: 117.0000 - accuracy: 0.9513 - precision: 0.9513 - recall: 0.9513 - auc: 0.9880 - prc: 0.9879 - val_loss: 0.3398 - val_tp: 687.0000 - val_fp: 113.0000 - val_tn: 687.0000 - val_fn: 113.0000 - val_accuracy: 0.8587 - val_precision: 0.8587 - val_recall: 0.8587 - val_auc: 0.9589 - val_prc: 0.9594
# Epoch 33/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1250 - tp: 2289.0000 - fp: 111.0000 - tn: 2289.0000 - fn: 111.0000 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9905 - prc: 0.9908 - val_loss: 0.2211 - val_tp: 738.0000 - val_fp: 62.0000 - val_tn: 738.0000 - val_fn: 62.0000 - val_accuracy: 0.9225 - val_precision: 0.9225 - val_recall: 0.9225 - val_auc: 0.9702 - val_prc: 0.9678
# Epoch 34/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1177 - tp: 2293.0000 - fp: 107.0000 - tn: 2293.0000 - fn: 107.0000 - accuracy: 0.9554 - precision: 0.9554 - recall: 0.9554 - auc: 0.9915 - prc: 0.9917 - val_loss: 0.1489 - val_tp: 760.0000 - val_fp: 40.0000 - val_tn: 760.0000 - val_fn: 40.0000 - val_accuracy: 0.9500 - val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9872 - val_prc: 0.9875
# Epoch 35/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.0785 - tp: 2337.0000 - fp: 63.0000 - tn: 2337.0000 - fn: 63.0000 - accuracy: 0.9737 - precision: 0.9737 - recall: 0.9737 - auc: 0.9959 - prc: 0.9958 - val_loss: 0.1518 - val_tp: 756.0000 - val_fp: 44.0000 - val_tn: 756.0000 - val_fn: 44.0000 - val_accuracy: 0.9450 - val_precision: 0.9450 - val_recall: 0.9450 - val_auc: 0.9852 - val_prc: 0.9837
# Epoch 36/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1224 - tp: 2294.0000 - fp: 106.0000 - tn: 2294.0000 - fn: 106.0000 - accuracy: 0.9558 - precision: 0.9558 - recall: 0.9558 - auc: 0.9900 - prc: 0.9895 - val_loss: 0.1644 - val_tp: 754.0000 - val_fp: 46.0000 - val_tn: 754.0000 - val_fn: 46.0000 - val_accuracy: 0.9425 - val_precision: 0.9425 - val_recall: 0.9425 - val_auc: 0.9815 - val_prc: 0.9792
# Epoch 37/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1136 - tp: 2292.0000 - fp: 108.0000 - tn: 2292.0000 - fn: 108.0000 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9917 - prc: 0.9914 - val_loss: 0.1501 - val_tp: 754.0000 - val_fp: 46.0000 - val_tn: 754.0000 - val_fn: 46.0000 - val_accuracy: 0.9425 - val_precision: 0.9425 - val_recall: 0.9425 - val_auc: 0.9846 - val_prc: 0.9834
# Epoch 38/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1061 - tp: 2303.0000 - fp: 97.0000 - tn: 2303.0000 - fn: 97.0000 - accuracy: 0.9596 - precision: 0.9596 - recall: 0.9596 - auc: 0.9927 - prc: 0.9927 - val_loss: 0.1767 - val_tp: 751.0000 - val_fp: 49.0000 - val_tn: 751.0000 - val_fn: 49.0000 - val_accuracy: 0.9388 - val_precision: 0.9388 - val_recall: 0.9388 - val_auc: 0.9801 - val_prc: 0.9780
# Epoch 39/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.1038 - tp: 2308.0000 - fp: 92.0000 - tn: 2308.0000 - fn: 92.0000 - accuracy: 0.9617 - precision: 0.9617 - recall: 0.9617 - auc: 0.9927 - prc: 0.9924 - val_loss: 0.1836 - val_tp: 747.0000 - val_fp: 53.0000 - val_tn: 747.0000 - val_fn: 53.0000 - val_accuracy: 0.9337 - val_precision: 0.9337 - val_recall: 0.9337 - val_auc: 0.9785 - val_prc: 0.9769
# Epoch 40/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1021 - tp: 2306.0000 - fp: 94.0000 - tn: 2306.0000 - fn: 94.0000 - accuracy: 0.9608 - precision: 0.9608 - recall: 0.9608 - auc: 0.9930 - prc: 0.9927 - val_loss: 0.1873 - val_tp: 742.0000 - val_fp: 58.0000 - val_tn: 742.0000 - val_fn: 58.0000 - val_accuracy: 0.9275 - val_precision: 0.9275 - val_recall: 0.9275 - val_auc: 0.9824 - val_prc: 0.9824
# Epoch 41/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1085 - tp: 2288.0000 - fp: 112.0000 - tn: 2288.0000 - fn: 112.0000 - accuracy: 0.9533 - precision: 0.9533 - recall: 0.9533 - auc: 0.9928 - prc: 0.9928 - val_loss: 0.1723 - val_tp: 748.0000 - val_fp: 52.0000 - val_tn: 748.0000 - val_fn: 52.0000 - val_accuracy: 0.9350 - val_precision: 0.9350 - val_recall: 0.9350 - val_auc: 0.9820 - val_prc: 0.9801
# Epoch 42/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.1147 - tp: 2286.0000 - fp: 114.0000 - tn: 2286.0000 - fn: 114.0000 - accuracy: 0.9525 - precision: 0.9525 - recall: 0.9525 - auc: 0.9919 - prc: 0.9919 - val_loss: 0.1868 - val_tp: 745.0000 - val_fp: 55.0000 - val_tn: 745.0000 - val_fn: 55.0000 - val_accuracy: 0.9312 - val_precision: 0.9312 - val_recall: 0.9312 - val_auc: 0.9791 - val_prc: 0.9771
# Epoch 43/100
# 75/75 [==============================] - 2s 25ms/step - loss: 0.0926 - tp: 2314.0000 - fp: 86.0000 - tn: 2314.0000 - fn: 86.0000 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9946 - prc: 0.9945 - val_loss: 0.1476 - val_tp: 759.0000 - val_fp: 41.0000 - val_tn: 759.0000 - val_fn: 41.0000 - val_accuracy: 0.9488 - val_precision: 0.9488 - val_recall: 0.9488 - val_auc: 0.9854 - val_prc: 0.9837
# Epoch 44/100
# 75/75 [==============================] - 2s 26ms/step - loss: 0.0928 - tp: 2315.0000 - fp: 85.0000 - tn: 2315.0000 - fn: 85.0000 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9943 - prc: 0.9943 - val_loss: 0.1719 - val_tp: 757.0000 - val_fp: 43.0000 - val_tn: 757.0000 - val_fn: 43.0000 - val_accuracy: 0.9463 - val_precision: 0.9463 - val_recall: 0.9463 - val_auc: 0.9826 - val_prc: 0.9798
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping

# %% [markdown]
# # Evaluation metrics

# %% [markdown]
# * ### plot functions

# %%
def plot_metrics(history):
    metrics = ['loss', 'prc', 'precision', 'recall']
    plt.figure(figsize=(10,10))
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch, history.history[metric], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
                 linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.8,1])
        else:
            plt.ylim([0,1])

        plt.legend()

# %%
def plot_cm(labels, predictions):
    cm = confusion_matrix(labels.argmax(axis=1), predictions.argmax(axis=1))
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix')
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

# %%
def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = sklearn.metrics.roc_curve(labels.argmax(axis=1), predictions.argmax(axis=1))
    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5,20])
    plt.ylim([80,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %%
def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = sklearn.metrics.precision_recall_curve(labels.argmax(axis=1),
                                                                  predictions.argmax(axis=1))

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# * ## Evaluation

# %% [markdown]
# * * #### Train history

# %%
plot_metrics(history)

# %% [markdown]
# * * #### Confusion Matrix

# %%
train_predictions_baseline = model.predict(X_train)
test_predictions_baseline = model.predict(X_test)

# %%
baseline_results = model.evaluate(X_test, y_test, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
print()

plot_cm(y_test, test_predictions_baseline)
# Out:
# loss :  0.19622419774532318
# tp :  744.0
# fp :  56.0
# tn :  744.0
# fn :  56.0
# accuracy :  0.9300000071525574
# precision :  0.9300000071525574
# recall :  0.9300000071525574
# auc :  0.9792921543121338
# prc :  0.9792569875717163

# %% [markdown]
# The model could be improved for the __Ship__ class

# %% [markdown]
# * * #### ROC Curve

# %%
plot_roc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# * *  #### AUPRC (precision-recall curve)

# %%
plot_prc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_prc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# # CNN

# %%
# Using a 3x3 kernel and a pooling size of 2x2 at the start of the sequence

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(80, 80, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(2, activation='softmax',bias_initializer=output_bias))

model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=METRICS)

# %%
history = model.fit(X_train, y_train,
                    epochs=EPOCHS,
                    callbacks=[early_stopping],
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 11s 113ms/step - loss: 0.5628 - tp: 2552.0000 - fp: 648.0000 - tn: 2552.0000 - fn: 648.0000 - accuracy: 0.7975 - precision: 0.7975 - recall: 0.7975 - auc: 0.8442 - prc: 0.8450 - val_loss: 0.5554 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.8098 - val_prc: 0.8054
# Epoch 2/100
# 75/75 [==============================] - 8s 101ms/step - loss: 0.5576 - tp: 1808.0000 - fp: 592.0000 - tn: 1808.0000 - fn: 592.0000 - accuracy: 0.7533 - precision: 0.7533 - recall: 0.7533 - auc: 0.7741 - prc: 0.7421 - val_loss: 0.5434 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.8278 - val_prc: 0.8261
# Epoch 3/100
# 75/75 [==============================] - 8s 102ms/step - loss: 0.5330 - tp: 1808.0000 - fp: 592.0000 - tn: 1808.0000 - fn: 592.0000 - accuracy: 0.7533 - precision: 0.7533 - recall: 0.7533 - auc: 0.8100 - prc: 0.7931 - val_loss: 0.5023 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.8891 - val_prc: 0.8933
# Epoch 4/100
# 75/75 [==============================] - 8s 103ms/step - loss: 0.4534 - tp: 1887.0000 - fp: 513.0000 - tn: 1887.0000 - fn: 513.0000 - accuracy: 0.7862 - precision: 0.7862 - recall: 0.7862 - auc: 0.8724 - prc: 0.8683 - val_loss: 0.3928 - val_tp: 671.0000 - val_fp: 129.0000 - val_tn: 671.0000 - val_fn: 129.0000 - val_accuracy: 0.8388 - val_precision: 0.8388 - val_recall: 0.8388 - val_auc: 0.9264 - val_prc: 0.9282
# Epoch 5/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.3760 - tp: 2027.0000 - fp: 373.0000 - tn: 2027.0000 - fn: 373.0000 - accuracy: 0.8446 - precision: 0.8446 - recall: 0.8446 - auc: 0.9118 - prc: 0.9100 - val_loss: 0.3552 - val_tp: 694.0000 - val_fp: 106.0000 - val_tn: 694.0000 - val_fn: 106.0000 - val_accuracy: 0.8675 - val_precision: 0.8675 - val_recall: 0.8675 - val_auc: 0.9365 - val_prc: 0.9377
# Epoch 6/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.3379 - tp: 2042.0000 - fp: 358.0000 - tn: 2042.0000 - fn: 358.0000 - accuracy: 0.8508 - precision: 0.8508 - recall: 0.8508 - auc: 0.9304 - prc: 0.9285 - val_loss: 0.3715 - val_tp: 681.0000 - val_fp: 119.0000 - val_tn: 681.0000 - val_fn: 119.0000 - val_accuracy: 0.8512 - val_precision: 0.8512 - val_recall: 0.8512 - val_auc: 0.9227 - val_prc: 0.9194
# Epoch 7/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.3122 - tp: 2056.0000 - fp: 344.0000 - tn: 2056.0000 - fn: 344.0000 - accuracy: 0.8567 - precision: 0.8567 - recall: 0.8567 - auc: 0.9410 - prc: 0.9421 - val_loss: 0.3063 - val_tp: 690.0000 - val_fp: 110.0000 - val_tn: 690.0000 - val_fn: 110.0000 - val_accuracy: 0.8625 - val_precision: 0.8625 - val_recall: 0.8625 - val_auc: 0.9466 - val_prc: 0.9484
# Epoch 8/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.2903 - tp: 2103.0000 - fp: 297.0000 - tn: 2103.0000 - fn: 297.0000 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9493 - prc: 0.9502 - val_loss: 0.2831 - val_tp: 697.0000 - val_fp: 103.0000 - val_tn: 697.0000 - val_fn: 103.0000 - val_accuracy: 0.8712 - val_precision: 0.8712 - val_recall: 0.8712 - val_auc: 0.9533 - val_prc: 0.9545
# Epoch 9/100
# 75/75 [==============================] - 8s 103ms/step - loss: 0.2829 - tp: 2103.0000 - fp: 297.0000 - tn: 2103.0000 - fn: 297.0000 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9517 - prc: 0.9520 - val_loss: 0.2793 - val_tp: 713.0000 - val_fp: 87.0000 - val_tn: 713.0000 - val_fn: 87.0000 - val_accuracy: 0.8913 - val_precision: 0.8913 - val_recall: 0.8913 - val_auc: 0.9541 - val_prc: 0.9543
# Epoch 10/100
# 75/75 [==============================] - 8s 103ms/step - loss: 0.2737 - tp: 2126.0000 - fp: 274.0000 - tn: 2126.0000 - fn: 274.0000 - accuracy: 0.8858 - precision: 0.8858 - recall: 0.8858 - auc: 0.9551 - prc: 0.9560 - val_loss: 0.2847 - val_tp: 697.0000 - val_fp: 103.0000 - val_tn: 697.0000 - val_fn: 103.0000 - val_accuracy: 0.8712 - val_precision: 0.8712 - val_recall: 0.8712 - val_auc: 0.9530 - val_prc: 0.9547
# Epoch 11/100
# 75/75 [==============================] - 9s 120ms/step - loss: 0.2700 - tp: 2110.0000 - fp: 290.0000 - tn: 2110.0000 - fn: 290.0000 - accuracy: 0.8792 - precision: 0.8792 - recall: 0.8792 - auc: 0.9558 - prc: 0.9567 - val_loss: 0.3196 - val_tp: 701.0000 - val_fp: 99.0000 - val_tn: 701.0000 - val_fn: 99.0000 - val_accuracy: 0.8763 - val_precision: 0.8763 - val_recall: 0.8763 - val_auc: 0.9447 - val_prc: 0.9382
# Epoch 12/100
# 75/75 [==============================] - 9s 121ms/step - loss: 0.2581 - tp: 2145.0000 - fp: 255.0000 - tn: 2145.0000 - fn: 255.0000 - accuracy: 0.8938 - precision: 0.8938 - recall: 0.8938 - auc: 0.9601 - prc: 0.9613 - val_loss: 0.2702 - val_tp: 707.0000 - val_fp: 93.0000 - val_tn: 707.0000 - val_fn: 93.0000 - val_accuracy: 0.8838 - val_precision: 0.8838 - val_recall: 0.8838 - val_auc: 0.9569 - val_prc: 0.9586
# Epoch 13/100
# 75/75 [==============================] - 9s 118ms/step - loss: 0.2555 - tp: 2135.0000 - fp: 265.0000 - tn: 2135.0000 - fn: 265.0000 - accuracy: 0.8896 - precision: 0.8896 - recall: 0.8896 - auc: 0.9605 - prc: 0.9614 - val_loss: 0.2847 - val_tp: 696.0000 - val_fp: 104.0000 - val_tn: 696.0000 - val_fn: 104.0000 - val_accuracy: 0.8700 - val_precision: 0.8700 - val_recall: 0.8700 - val_auc: 0.9539 - val_prc: 0.9557
# Epoch 14/100
# 75/75 [==============================] - 8s 100ms/step - loss: 0.2377 - tp: 2158.0000 - fp: 242.0000 - tn: 2158.0000 - fn: 242.0000 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9663 - prc: 0.9676 - val_loss: 0.2378 - val_tp: 732.0000 - val_fp: 68.0000 - val_tn: 732.0000 - val_fn: 68.0000 - val_accuracy: 0.9150 - val_precision: 0.9150 - val_recall: 0.9150 - val_auc: 0.9668 - val_prc: 0.9675
# Epoch 15/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.2465 - tp: 2155.0000 - fp: 245.0000 - tn: 2155.0000 - fn: 245.0000 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9641 - prc: 0.9654 - val_loss: 0.2535 - val_tp: 715.0000 - val_fp: 85.0000 - val_tn: 715.0000 - val_fn: 85.0000 - val_accuracy: 0.8938 - val_precision: 0.8938 - val_recall: 0.8938 - val_auc: 0.9643 - val_prc: 0.9650
# Epoch 16/100
# 75/75 [==============================] - 7s 97ms/step - loss: 0.2660 - tp: 2129.0000 - fp: 271.0000 - tn: 2129.0000 - fn: 271.0000 - accuracy: 0.8871 - precision: 0.8871 - recall: 0.8871 - auc: 0.9582 - prc: 0.9583 - val_loss: 0.2743 - val_tp: 706.0000 - val_fp: 94.0000 - val_tn: 706.0000 - val_fn: 94.0000 - val_accuracy: 0.8825 - val_precision: 0.8825 - val_recall: 0.8825 - val_auc: 0.9547 - val_prc: 0.9551
# Epoch 17/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.2592 - tp: 2129.0000 - fp: 271.0000 - tn: 2129.0000 - fn: 271.0000 - accuracy: 0.8871 - precision: 0.8871 - recall: 0.8871 - auc: 0.9609 - prc: 0.9619 - val_loss: 0.2620 - val_tp: 720.0000 - val_fp: 80.0000 - val_tn: 720.0000 - val_fn: 80.0000 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9601 - val_prc: 0.9600
# Epoch 18/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.2477 - tp: 2138.0000 - fp: 262.0000 - tn: 2138.0000 - fn: 262.0000 - accuracy: 0.8908 - precision: 0.8908 - recall: 0.8908 - auc: 0.9638 - prc: 0.9649 - val_loss: 0.2589 - val_tp: 718.0000 - val_fp: 82.0000 - val_tn: 718.0000 - val_fn: 82.0000 - val_accuracy: 0.8975 - val_precision: 0.8975 - val_recall: 0.8975 - val_auc: 0.9597 - val_prc: 0.9596
# Epoch 19/100
# 75/75 [==============================] - 7s 97ms/step - loss: 0.2420 - tp: 2133.0000 - fp: 267.0000 - tn: 2133.0000 - fn: 267.0000 - accuracy: 0.8888 - precision: 0.8888 - recall: 0.8888 - auc: 0.9655 - prc: 0.9670 - val_loss: 0.2547 - val_tp: 715.0000 - val_fp: 85.0000 - val_tn: 715.0000 - val_fn: 85.0000 - val_accuracy: 0.8938 - val_precision: 0.8938 - val_recall: 0.8938 - val_auc: 0.9607 - val_prc: 0.9614
# Epoch 20/100
# 75/75 [==============================] - 7s 96ms/step - loss: 0.2266 - tp: 2173.0000 - fp: 227.0000 - tn: 2173.0000 - fn: 227.0000 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9699 - prc: 0.9712 - val_loss: 0.2350 - val_tp: 729.0000 - val_fp: 71.0000 - val_tn: 729.0000 - val_fn: 71.0000 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9673 - val_prc: 0.9675
# Epoch 21/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.2143 - tp: 2190.0000 - fp: 210.0000 - tn: 2190.0000 - fn: 210.0000 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9731 - prc: 0.9742 - val_loss: 0.2289 - val_tp: 734.0000 - val_fp: 66.0000 - val_tn: 734.0000 - val_fn: 66.0000 - val_accuracy: 0.9175 - val_precision: 0.9175 - val_recall: 0.9175 - val_auc: 0.9684 - val_prc: 0.9685
# Epoch 22/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.2042 - tp: 2198.0000 - fp: 202.0000 - tn: 2198.0000 - fn: 202.0000 - accuracy: 0.9158 - precision: 0.9158 - recall: 0.9158 - auc: 0.9755 - prc: 0.9764 - val_loss: 0.2189 - val_tp: 737.0000 - val_fp: 63.0000 - val_tn: 737.0000 - val_fn: 63.0000 - val_accuracy: 0.9212 - val_precision: 0.9212 - val_recall: 0.9212 - val_auc: 0.9724 - val_prc: 0.9728
# Epoch 23/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.1993 - tp: 2189.0000 - fp: 211.0000 - tn: 2189.0000 - fn: 211.0000 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9766 - prc: 0.9775 - val_loss: 0.2303 - val_tp: 725.0000 - val_fp: 75.0000 - val_tn: 725.0000 - val_fn: 75.0000 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9682 - val_prc: 0.9683
# Epoch 24/100
# 75/75 [==============================] - 8s 108ms/step - loss: 0.2104 - tp: 2189.0000 - fp: 211.0000 - tn: 2189.0000 - fn: 211.0000 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9736 - prc: 0.9744 - val_loss: 0.2152 - val_tp: 736.0000 - val_fp: 64.0000 - val_tn: 736.0000 - val_fn: 64.0000 - val_accuracy: 0.9200 - val_precision: 0.9200 - val_recall: 0.9200 - val_auc: 0.9719 - val_prc: 0.9717
# Epoch 25/100
# 75/75 [==============================] - 8s 101ms/step - loss: 0.1909 - tp: 2216.0000 - fp: 184.0000 - tn: 2216.0000 - fn: 184.0000 - accuracy: 0.9233 - precision: 0.9233 - recall: 0.9233 - auc: 0.9783 - prc: 0.9787 - val_loss: 0.2214 - val_tp: 723.0000 - val_fp: 77.0000 - val_tn: 723.0000 - val_fn: 77.0000 - val_accuracy: 0.9038 - val_precision: 0.9038 - val_recall: 0.9038 - val_auc: 0.9712 - val_prc: 0.9718
# Epoch 26/100
# 75/75 [==============================] - 8s 109ms/step - loss: 0.1767 - tp: 2237.0000 - fp: 163.0000 - tn: 2237.0000 - fn: 163.0000 - accuracy: 0.9321 - precision: 0.9321 - recall: 0.9321 - auc: 0.9816 - prc: 0.9822 - val_loss: 0.2097 - val_tp: 738.0000 - val_fp: 62.0000 - val_tn: 738.0000 - val_fn: 62.0000 - val_accuracy: 0.9225 - val_precision: 0.9225 - val_recall: 0.9225 - val_auc: 0.9731 - val_prc: 0.9735
# Epoch 27/100
# 75/75 [==============================] - 9s 123ms/step - loss: 0.1755 - tp: 2225.0000 - fp: 175.0000 - tn: 2225.0000 - fn: 175.0000 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9819 - prc: 0.9826 - val_loss: 0.2014 - val_tp: 730.0000 - val_fp: 70.0000 - val_tn: 730.0000 - val_fn: 70.0000 - val_accuracy: 0.9125 - val_precision: 0.9125 - val_recall: 0.9125 - val_auc: 0.9750 - val_prc: 0.9754
# Epoch 28/100
# 75/75 [==============================] - 8s 106ms/step - loss: 0.1637 - tp: 2242.0000 - fp: 158.0000 - tn: 2242.0000 - fn: 158.0000 - accuracy: 0.9342 - precision: 0.9342 - recall: 0.9342 - auc: 0.9843 - prc: 0.9848 - val_loss: 0.2268 - val_tp: 726.0000 - val_fp: 74.0000 - val_tn: 726.0000 - val_fn: 74.0000 - val_accuracy: 0.9075 - val_precision: 0.9075 - val_recall: 0.9075 - val_auc: 0.9703 - val_prc: 0.9709
# Epoch 29/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.1593 - tp: 2243.0000 - fp: 157.0000 - tn: 2243.0000 - fn: 157.0000 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9852 - prc: 0.9857 - val_loss: 0.1829 - val_tp: 741.0000 - val_fp: 59.0000 - val_tn: 741.0000 - val_fn: 59.0000 - val_accuracy: 0.9262 - val_precision: 0.9262 - val_recall: 0.9262 - val_auc: 0.9792 - val_prc: 0.9795
# Epoch 30/100
# 75/75 [==============================] - 8s 104ms/step - loss: 0.1455 - tp: 2270.0000 - fp: 130.0000 - tn: 2270.0000 - fn: 130.0000 - accuracy: 0.9458 - precision: 0.9458 - recall: 0.9458 - auc: 0.9876 - prc: 0.9880 - val_loss: 0.1964 - val_tp: 742.0000 - val_fp: 58.0000 - val_tn: 742.0000 - val_fn: 58.0000 - val_accuracy: 0.9275 - val_precision: 0.9275 - val_recall: 0.9275 - val_auc: 0.9767 - val_prc: 0.9758
# Epoch 31/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.1595 - tp: 2244.0000 - fp: 156.0000 - tn: 2244.0000 - fn: 156.0000 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9848 - prc: 0.9853 - val_loss: 0.2400 - val_tp: 719.0000 - val_fp: 81.0000 - val_tn: 719.0000 - val_fn: 81.0000 - val_accuracy: 0.8988 - val_precision: 0.8988 - val_recall: 0.8988 - val_auc: 0.9652 - val_prc: 0.9642
# Epoch 32/100
# 75/75 [==============================] - 8s 105ms/step - loss: 0.1497 - tp: 2241.0000 - fp: 159.0000 - tn: 2241.0000 - fn: 159.0000 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9866 - prc: 0.9871 - val_loss: 0.1968 - val_tp: 747.0000 - val_fp: 53.0000 - val_tn: 747.0000 - val_fn: 53.0000 - val_accuracy: 0.9337 - val_precision: 0.9337 - val_recall: 0.9337 - val_auc: 0.9752 - val_prc: 0.9733
# Epoch 33/100
# 75/75 [==============================] - 8s 106ms/step - loss: 0.1356 - tp: 2260.0000 - fp: 140.0000 - tn: 2260.0000 - fn: 140.0000 - accuracy: 0.9417 - precision: 0.9417 - recall: 0.9417 - auc: 0.9894 - prc: 0.9898 - val_loss: 0.1844 - val_tp: 741.0000 - val_fp: 59.0000 - val_tn: 741.0000 - val_fn: 59.0000 - val_accuracy: 0.9262 - val_precision: 0.9262 - val_recall: 0.9262 - val_auc: 0.9776 - val_prc: 0.9756
# Epoch 34/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.1334 - tp: 2267.0000 - fp: 133.0000 - tn: 2267.0000 - fn: 133.0000 - accuracy: 0.9446 - precision: 0.9446 - recall: 0.9446 - auc: 0.9897 - prc: 0.9900 - val_loss: 0.1715 - val_tp: 752.0000 - val_fp: 48.0000 - val_tn: 752.0000 - val_fn: 48.0000 - val_accuracy: 0.9400 - val_precision: 0.9400 - val_recall: 0.9400 - val_auc: 0.9813 - val_prc: 0.9803
# Epoch 35/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.1311 - tp: 2272.0000 - fp: 128.0000 - tn: 2272.0000 - fn: 128.0000 - accuracy: 0.9467 - precision: 0.9467 - recall: 0.9467 - auc: 0.9898 - prc: 0.9901 - val_loss: 0.1938 - val_tp: 731.0000 - val_fp: 69.0000 - val_tn: 731.0000 - val_fn: 69.0000 - val_accuracy: 0.9137 - val_precision: 0.9137 - val_recall: 0.9137 - val_auc: 0.9771 - val_prc: 0.9777
# Epoch 36/100
# 75/75 [==============================] - 8s 103ms/step - loss: 0.1156 - tp: 2287.0000 - fp: 113.0000 - tn: 2287.0000 - fn: 113.0000 - accuracy: 0.9529 - precision: 0.9529 - recall: 0.9529 - auc: 0.9925 - prc: 0.9927 - val_loss: 0.2071 - val_tp: 731.0000 - val_fp: 69.0000 - val_tn: 731.0000 - val_fn: 69.0000 - val_accuracy: 0.9137 - val_precision: 0.9137 - val_recall: 0.9137 - val_auc: 0.9758 - val_prc: 0.9766
# Epoch 37/100
# 75/75 [==============================] - 8s 102ms/step - loss: 0.1144 - tp: 2291.0000 - fp: 109.0000 - tn: 2291.0000 - fn: 109.0000 - accuracy: 0.9546 - precision: 0.9546 - recall: 0.9546 - auc: 0.9924 - prc: 0.9927 - val_loss: 0.1740 - val_tp: 740.0000 - val_fp: 60.0000 - val_tn: 740.0000 - val_fn: 60.0000 - val_accuracy: 0.9250 - val_precision: 0.9250 - val_recall: 0.9250 - val_auc: 0.9814 - val_prc: 0.9818
# Epoch 38/100
# 75/75 [==============================] - 8s 101ms/step - loss: 0.0990 - tp: 2295.0000 - fp: 105.0000 - tn: 2295.0000 - fn: 105.0000 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9946 - prc: 0.9947 - val_loss: 0.1531 - val_tp: 753.0000 - val_fp: 47.0000 - val_tn: 753.0000 - val_fn: 47.0000 - val_accuracy: 0.9413 - val_precision: 0.9413 - val_recall: 0.9413 - val_auc: 0.9845 - val_prc: 0.9833
# Epoch 39/100
# 75/75 [==============================] - 8s 101ms/step - loss: 0.0909 - tp: 2314.0000 - fp: 86.0000 - tn: 2314.0000 - fn: 86.0000 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9954 - prc: 0.9955 - val_loss: 0.1705 - val_tp: 751.0000 - val_fp: 49.0000 - val_tn: 751.0000 - val_fn: 49.0000 - val_accuracy: 0.9388 - val_precision: 0.9388 - val_recall: 0.9388 - val_auc: 0.9826 - val_prc: 0.9818
# Epoch 40/100
# 75/75 [==============================] - 8s 102ms/step - loss: 0.0851 - tp: 2319.0000 - fp: 81.0000 - tn: 2319.0000 - fn: 81.0000 - accuracy: 0.9663 - precision: 0.9663 - recall: 0.9663 - auc: 0.9962 - prc: 0.9963 - val_loss: 0.1553 - val_tp: 755.0000 - val_fp: 45.0000 - val_tn: 755.0000 - val_fn: 45.0000 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9836 - val_prc: 0.9816
# Epoch 41/100
# 75/75 [==============================] - 8s 103ms/step - loss: 0.0954 - tp: 2308.0000 - fp: 92.0000 - tn: 2308.0000 - fn: 92.0000 - accuracy: 0.9617 - precision: 0.9617 - recall: 0.9617 - auc: 0.9946 - prc: 0.9948 - val_loss: 0.1477 - val_tp: 753.0000 - val_fp: 47.0000 - val_tn: 753.0000 - val_fn: 47.0000 - val_accuracy: 0.9413 - val_precision: 0.9413 - val_recall: 0.9413 - val_auc: 0.9862 - val_prc: 0.9865
# Epoch 42/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0870 - tp: 2327.0000 - fp: 73.0000 - tn: 2327.0000 - fn: 73.0000 - accuracy: 0.9696 - precision: 0.9696 - recall: 0.9696 - auc: 0.9959 - prc: 0.9960 - val_loss: 0.1712 - val_tp: 748.0000 - val_fp: 52.0000 - val_tn: 748.0000 - val_fn: 52.0000 - val_accuracy: 0.9350 - val_precision: 0.9350 - val_recall: 0.9350 - val_auc: 0.9812 - val_prc: 0.9786
# Epoch 43/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0858 - tp: 2320.0000 - fp: 80.0000 - tn: 2320.0000 - fn: 80.0000 - accuracy: 0.9667 - precision: 0.9667 - recall: 0.9667 - auc: 0.9958 - prc: 0.9959 - val_loss: 0.1554 - val_tp: 754.0000 - val_fp: 46.0000 - val_tn: 754.0000 - val_fn: 46.0000 - val_accuracy: 0.9425 - val_precision: 0.9425 - val_recall: 0.9425 - val_auc: 0.9848 - val_prc: 0.9833
# Epoch 44/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.0716 - tp: 2335.0000 - fp: 65.0000 - tn: 2335.0000 - fn: 65.0000 - accuracy: 0.9729 - precision: 0.9729 - recall: 0.9729 - auc: 0.9973 - prc: 0.9974 - val_loss: 0.1589 - val_tp: 756.0000 - val_fp: 44.0000 - val_tn: 756.0000 - val_fn: 44.0000 - val_accuracy: 0.9450 - val_precision: 0.9450 - val_recall: 0.9450 - val_auc: 0.9844 - val_prc: 0.9825
# Epoch 45/100
# 75/75 [==============================] - 8s 103ms/step - loss: 0.0660 - tp: 2339.0000 - fp: 61.0000 - tn: 2339.0000 - fn: 61.0000 - accuracy: 0.9746 - precision: 0.9746 - recall: 0.9746 - auc: 0.9977 - prc: 0.9978 - val_loss: 0.1623 - val_tp: 755.0000 - val_fp: 45.0000 - val_tn: 755.0000 - val_fn: 45.0000 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9844 - val_prc: 0.9820
# Epoch 46/100
# 75/75 [==============================] - 7s 97ms/step - loss: 0.0724 - tp: 2329.0000 - fp: 71.0000 - tn: 2329.0000 - fn: 71.0000 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9970 - prc: 0.9971 - val_loss: 0.1596 - val_tp: 756.0000 - val_fp: 44.0000 - val_tn: 756.0000 - val_fn: 44.0000 - val_accuracy: 0.9450 - val_precision: 0.9450 - val_recall: 0.9450 - val_auc: 0.9834 - val_prc: 0.9803
# Epoch 47/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0566 - tp: 2351.0000 - fp: 49.0000 - tn: 2351.0000 - fn: 49.0000 - accuracy: 0.9796 - precision: 0.9796 - recall: 0.9796 - auc: 0.9984 - prc: 0.9985 - val_loss: 0.1347 - val_tp: 760.0000 - val_fp: 40.0000 - val_tn: 760.0000 - val_fn: 40.0000 - val_accuracy: 0.9500 - val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9889 - val_prc: 0.9892
# Epoch 48/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0647 - tp: 2333.0000 - fp: 67.0000 - tn: 2333.0000 - fn: 67.0000 - accuracy: 0.9721 - precision: 0.9721 - recall: 0.9721 - auc: 0.9977 - prc: 0.9977 - val_loss: 0.1387 - val_tp: 757.0000 - val_fp: 43.0000 - val_tn: 757.0000 - val_fn: 43.0000 - val_accuracy: 0.9463 - val_precision: 0.9463 - val_recall: 0.9463 - val_auc: 0.9874 - val_prc: 0.9865
# Epoch 49/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0497 - tp: 2358.0000 - fp: 42.0000 - tn: 2358.0000 - fn: 42.0000 - accuracy: 0.9825 - precision: 0.9825 - recall: 0.9825 - auc: 0.9988 - prc: 0.9988 - val_loss: 0.1376 - val_tp: 761.0000 - val_fp: 39.0000 - val_tn: 761.0000 - val_fn: 39.0000 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9873 - val_prc: 0.9863
# Epoch 50/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0642 - tp: 2342.0000 - fp: 58.0000 - tn: 2342.0000 - fn: 58.0000 - accuracy: 0.9758 - precision: 0.9758 - recall: 0.9758 - auc: 0.9976 - prc: 0.9976 - val_loss: 0.1592 - val_tp: 757.0000 - val_fp: 43.0000 - val_tn: 757.0000 - val_fn: 43.0000 - val_accuracy: 0.9463 - val_precision: 0.9463 - val_recall: 0.9463 - val_auc: 0.9841 - val_prc: 0.9812
# Epoch 51/100
# 75/75 [==============================] - 7s 99ms/step - loss: 0.0558 - tp: 2349.0000 - fp: 51.0000 - tn: 2349.0000 - fn: 51.0000 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9983 - prc: 0.9983 - val_loss: 0.1558 - val_tp: 761.0000 - val_fp: 39.0000 - val_tn: 761.0000 - val_fn: 39.0000 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9849 - val_prc: 0.9820
# Epoch 52/100
# 75/75 [==============================] - 8s 102ms/step - loss: 0.0475 - tp: 2363.0000 - fp: 37.0000 - tn: 2363.0000 - fn: 37.0000 - accuracy: 0.9846 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - prc: 0.9989 - val_loss: 0.1656 - val_tp: 760.0000 - val_fp: 40.0000 - val_tn: 760.0000 - val_fn: 40.0000 - val_accuracy: 0.9500 - val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9847 - val_prc: 0.98198.0000 - fn: 18.0000 - accuracy: 0.9830 - precision: 0.9830 -
# Epoch 53/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0426 - tp: 2368.0000 - fp: 32.0000 - tn: 2368.0000 - fn: 32.0000 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9990 - prc: 0.9991 - val_loss: 0.1449 - val_tp: 761.0000 - val_fp: 39.0000 - val_tn: 761.0000 - val_fn: 39.0000 - val_accuracy: 0.9513 - val_precision: 0.9513 - val_recall: 0.9513 - val_auc: 0.9859 - val_prc: 0.9831
# Epoch 54/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0412 - tp: 2368.0000 - fp: 32.0000 - tn: 2368.0000 - fn: 32.0000 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9992 - prc: 0.9992 - val_loss: 0.1453 - val_tp: 765.0000 - val_fp: 35.0000 - val_tn: 765.0000 - val_fn: 35.0000 - val_accuracy: 0.9563 - val_precision: 0.9563 - val_recall: 0.9563 - val_auc: 0.9859 - val_prc: 0.9830
# Epoch 55/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0565 - tp: 2346.0000 - fp: 54.0000 - tn: 2346.0000 - fn: 54.0000 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9978 - prc: 0.9976 - val_loss: 0.1343 - val_tp: 765.0000 - val_fp: 35.0000 - val_tn: 765.0000 - val_fn: 35.0000 - val_accuracy: 0.9563 - val_precision: 0.9563 - val_recall: 0.9563 - val_auc: 0.9859 - val_prc: 0.9829
# Epoch 56/100
# 75/75 [==============================] - 7s 98ms/step - loss: 0.0394 - tp: 2369.0000 - fp: 31.0000 - tn: 2369.0000 - fn: 31.0000 - accuracy: 0.9871 - precision: 0.9871 - recall: 0.9871 - auc: 0.9992 - prc: 0.9992 - val_loss: 0.1604 - val_tp: 757.0000 - val_fp: 43.0000 - val_tn: 757.0000 - val_fn: 43.0000 - val_accuracy: 0.9463 - val_precision: 0.9463 - val_recall: 0.9463 - val_auc: 0.9839 - val_prc: 0.9815
# Epoch 57/100
# 75/75 [==============================] - 7s 100ms/step - loss: 0.0348 - tp: 2367.0000 - fp: 33.0000 - tn: 2367.0000 - fn: 33.0000 - accuracy: 0.9862 - precision: 0.9862 - recall: 0.9862 - auc: 0.9994 - prc: 0.9994 - val_loss: 0.1695 - val_tp: 762.0000 - val_fp: 38.0000 - val_tn: 762.0000 - val_fn: 38.0000 - val_accuracy: 0.9525 - val_precision: 0.9525 - val_recall: 0.9525 - val_auc: 0.9846 - val_prc: 0.9813000 - fn: 12.0000 - accuracy: 0.9879 - precision: 0.9879 - recall: 0.9879 - auc: 0.9995 - prc: 0.999 - ETA: 3s - loss: 0.0340 - tp: 1012.0000 - fp: 12.0000 - tn: 1012.0000 - fn: 12.0000 - accuracy: 0.9883 - precision: 0.9883
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping

# %%
plot_metrics(history)

# %% [markdown]
# We see that the best epoch is the 47th, the training ended 10 epochs later.

# %% [markdown]
# * * #### Confusion Matrix

# %%
train_predictions_baseline = model.predict(X_train)
test_predictions_baseline = model.predict(X_test)

# %%
baseline_results = model.evaluate(X_test, y_test, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
print()

plot_cm(y_test, test_predictions_baseline)
# Out:
# loss :  0.14200299978256226
# tp :  755.0
# fp :  45.0
# tn :  755.0
# fn :  45.0
# accuracy :  0.9437500238418579
# precision :  0.9437500238418579
# recall :  0.9437500238418579
# auc :  0.9879631400108337
# prc :  0.987646222114563

# %% [markdown]
# Big improvement on the positive class (__Ship__) prediction

# %% [markdown]
# * * #### ROC Curve

# %%
plot_roc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# * *  #### AUPRC (precision-recall curve)

# %%
plot_prc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_prc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# The model has a clear improvement

# %% [markdown]
# ## Adding a Layer to the CNN

# %%
model = Sequential()
model.add(Conv2D(64, (5, 5), input_shape=(80, 80, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(32, (3, 3), input_shape=(80, 80, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(2, activation='softmax',bias_initializer=output_bias))

model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=METRICS)

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 76, 76, 64)        4864
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 23, 23, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 3872)              0
# _________________________________________________________________
# dense_38 (Dense)             (None, 100)               387300
# _________________________________________________________________
# dense_39 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_40 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 420,930
# Trainable params: 420,930
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,
                    epochs=EPOCHS,
                    callbacks=[early_stopping],
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 15s 175ms/step - loss: 0.5784 - tp: 2563.0000 - fp: 637.0000 - tn: 2563.0000 - fn: 637.0000 - accuracy: 0.8009 - precision: 0.8009 - recall: 0.8009 - auc: 0.8364 - prc: 0.8371 - val_loss: 0.5596 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.7757 - val_prc: 0.7676
# Epoch 2/100
# 75/75 [==============================] - 13s 169ms/step - loss: 0.5632 - tp: 1808.0000 - fp: 592.0000 - tn: 1808.0000 - fn: 592.0000 - accuracy: 0.7533 - precision: 0.7533 - recall: 0.7533 - auc: 0.7611 - prc: 0.7234 - val_loss: 0.5650 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.7815 - val_prc: 0.7719
# Epoch 3/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.5607 - tp: 1808.0000 - fp: 592.0000 - tn: 1808.0000 - fn: 592.0000 - accuracy: 0.7533 - precision: 0.7533 - recall: 0.7533 - auc: 0.7576 - prc: 0.7281 - val_loss: 0.5594 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.7842 - val_prc: 0.7761
# Epoch 4/100
# 75/75 [==============================] - 13s 174ms/step - loss: 0.5516 - tp: 1808.0000 - fp: 592.0000 - tn: 1808.0000 - fn: 592.0000 - accuracy: 0.7533 - precision: 0.7533 - recall: 0.7533 - auc: 0.7845 - prc: 0.7637 - val_loss: 0.5511 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.7937 - val_prc: 0.7866
# Epoch 5/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.5505 - tp: 1808.0000 - fp: 592.0000 - tn: 1808.0000 - fn: 592.0000 - accuracy: 0.7533 - precision: 0.7533 - recall: 0.7533 - auc: 0.7831 - prc: 0.7640 - val_loss: 0.5402 - val_tp: 601.0000 - val_fp: 199.0000 - val_tn: 601.0000 - val_fn: 199.0000 - val_accuracy: 0.7513 - val_precision: 0.7513 - val_recall: 0.7513 - val_auc: 0.8062 - val_prc: 0.8008
# Epoch 6/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.5092 - tp: 1823.0000 - fp: 577.0000 - tn: 1823.0000 - fn: 577.0000 - accuracy: 0.7596 - precision: 0.7596 - recall: 0.7596 - auc: 0.8310 - prc: 0.8192 - val_loss: 0.4702 - val_tp: 631.0000 - val_fp: 169.0000 - val_tn: 631.0000 - val_fn: 169.0000 - val_accuracy: 0.7887 - val_precision: 0.7887 - val_recall: 0.7887 - val_auc: 0.8572 - val_prc: 0.8520
# Epoch 7/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.4272 - tp: 1968.0000 - fp: 432.0000 - tn: 1968.0000 - fn: 432.0000 - accuracy: 0.8200 - precision: 0.8200 - recall: 0.8200 - auc: 0.8835 - prc: 0.8802 - val_loss: 0.4295 - val_tp: 658.0000 - val_fp: 142.0000 - val_tn: 658.0000 - val_fn: 142.0000 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8893 - val_prc: 0.8803
# Epoch 8/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.4054 - tp: 1989.0000 - fp: 411.0000 - tn: 1989.0000 - fn: 411.0000 - accuracy: 0.8288 - precision: 0.8288 - recall: 0.8288 - auc: 0.8954 - prc: 0.8936 - val_loss: 0.4283 - val_tp: 653.0000 - val_fp: 147.0000 - val_tn: 653.0000 - val_fn: 147.0000 - val_accuracy: 0.8163 - val_precision: 0.8163 - val_recall: 0.8163 - val_auc: 0.8989 - val_prc: 0.8934
# Epoch 9/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.3616 - tp: 2034.0000 - fp: 366.0000 - tn: 2034.0000 - fn: 366.0000 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9192 - prc: 0.9153 - val_loss: 0.4197 - val_tp: 649.0000 - val_fp: 151.0000 - val_tn: 649.0000 - val_fn: 151.0000 - val_accuracy: 0.8112 - val_precision: 0.8112 - val_recall: 0.8112 - val_auc: 0.9052 - val_prc: 0.9020
# Epoch 10/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.3596 - tp: 2013.0000 - fp: 387.0000 - tn: 2013.0000 - fn: 387.0000 - accuracy: 0.8388 - precision: 0.8388 - recall: 0.8388 - auc: 0.9205 - prc: 0.9185 - val_loss: 0.3819 - val_tp: 667.0000 - val_fp: 133.0000 - val_tn: 667.0000 - val_fn: 133.0000 - val_accuracy: 0.8338 - val_precision: 0.8338 - val_recall: 0.8338 - val_auc: 0.9142 - val_prc: 0.9093
# Epoch 11/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.3510 - tp: 2031.0000 - fp: 369.0000 - tn: 2031.0000 - fn: 369.0000 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9244 - prc: 0.9225 - val_loss: 0.4400 - val_tp: 654.0000 - val_fp: 146.0000 - val_tn: 654.0000 - val_fn: 146.0000 - val_accuracy: 0.8175 - val_precision: 0.8175 - val_recall: 0.8175 - val_auc: 0.9121 - val_prc: 0.9087
# Epoch 12/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.3185 - tp: 2078.0000 - fp: 322.0000 - tn: 2078.0000 - fn: 322.0000 - accuracy: 0.8658 - precision: 0.8658 - recall: 0.8658 - auc: 0.9384 - prc: 0.9370 - val_loss: 0.3465 - val_tp: 686.0000 - val_fp: 114.0000 - val_tn: 686.0000 - val_fn: 114.0000 - val_accuracy: 0.8575 - val_precision: 0.8575 - val_recall: 0.8575 - val_auc: 0.9300 - val_prc: 0.9244
# Epoch 13/100
# 75/75 [==============================] - 13s 173ms/step - loss: 0.2995 - tp: 2090.0000 - fp: 310.0000 - tn: 2090.0000 - fn: 310.0000 - accuracy: 0.8708 - precision: 0.8708 - recall: 0.8708 - auc: 0.9455 - prc: 0.9434 - val_loss: 0.3094 - val_tp: 702.0000 - val_fp: 98.0000 - val_tn: 702.0000 - val_fn: 98.0000 - val_accuracy: 0.8775 - val_precision: 0.8775 - val_recall: 0.8775 - val_auc: 0.9407 - val_prc: 0.9350
# Epoch 14/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.2915 - tp: 2109.0000 - fp: 291.0000 - tn: 2109.0000 - fn: 291.0000 - accuracy: 0.8788 - precision: 0.8788 - recall: 0.8788 - auc: 0.9485 - prc: 0.9457 - val_loss: 0.3318 - val_tp: 689.0000 - val_fp: 111.0000 - val_tn: 689.0000 - val_fn: 111.0000 - val_accuracy: 0.8612 - val_precision: 0.8612 - val_recall: 0.8612 - val_auc: 0.9345 - val_prc: 0.9306
# Epoch 15/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.3173 - tp: 2085.0000 - fp: 315.0000 - tn: 2085.0000 - fn: 315.0000 - accuracy: 0.8687 - precision: 0.8687 - recall: 0.8687 - auc: 0.9387 - prc: 0.9363 - val_loss: 0.3568 - val_tp: 688.0000 - val_fp: 112.0000 - val_tn: 688.0000 - val_fn: 112.0000 - val_accuracy: 0.8600 - val_precision: 0.8600 - val_recall: 0.8600 - val_auc: 0.9367 - val_prc: 0.9326
# Epoch 16/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.2799 - tp: 2148.0000 - fp: 252.0000 - tn: 2148.0000 - fn: 252.0000 - accuracy: 0.8950 - precision: 0.8950 - recall: 0.8950 - auc: 0.9518 - prc: 0.9488 - val_loss: 0.2870 - val_tp: 713.0000 - val_fp: 87.0000 - val_tn: 713.0000 - val_fn: 87.0000 - val_accuracy: 0.8913 - val_precision: 0.8913 - val_recall: 0.8913 - val_auc: 0.9507 - val_prc: 0.9456
# Epoch 17/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.2706 - tp: 2128.0000 - fp: 272.0000 - tn: 2128.0000 - fn: 272.0000 - accuracy: 0.8867 - precision: 0.8867 - recall: 0.8867 - auc: 0.9551 - prc: 0.9540 - val_loss: 0.2836 - val_tp: 721.0000 - val_fp: 79.0000 - val_tn: 721.0000 - val_fn: 79.0000 - val_accuracy: 0.9013 - val_precision: 0.9013 - val_recall: 0.9013 - val_auc: 0.9508 - val_prc: 0.9485
# Epoch 18/100
# 75/75 [==============================] - 13s 171ms/step - loss: 0.2429 - tp: 2161.0000 - fp: 239.0000 - tn: 2161.0000 - fn: 239.0000 - accuracy: 0.9004 - precision: 0.9004 - recall: 0.9004 - auc: 0.9637 - prc: 0.9626 - val_loss: 0.3179 - val_tp: 716.0000 - val_fp: 84.0000 - val_tn: 716.0000 - val_fn: 84.0000 - val_accuracy: 0.8950 - val_precision: 0.8950 - val_recall: 0.8950 - val_auc: 0.9505 - val_prc: 0.9472
# Epoch 19/100
# 75/75 [==============================] - 13s 171ms/step - loss: 0.2507 - tp: 2156.0000 - fp: 244.0000 - tn: 2156.0000 - fn: 244.0000 - accuracy: 0.8983 - precision: 0.8983 - recall: 0.8983 - auc: 0.9614 - prc: 0.9611 - val_loss: 0.2564 - val_tp: 723.0000 - val_fp: 77.0000 - val_tn: 723.0000 - val_fn: 77.0000 - val_accuracy: 0.9038 - val_precision: 0.9038 - val_recall: 0.9038 - val_auc: 0.9589 - val_prc: 0.9566
# Epoch 20/100
# 75/75 [==============================] - 13s 167ms/step - loss: 0.2196 - tp: 2190.0000 - fp: 210.0000 - tn: 2190.0000 - fn: 210.0000 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9703 - prc: 0.9698 - val_loss: 0.2561 - val_tp: 711.0000 - val_fp: 89.0000 - val_tn: 711.0000 - val_fn: 89.0000 - val_accuracy: 0.8888 - val_precision: 0.8888 - val_recall: 0.8888 - val_auc: 0.9592 - val_prc: 0.9580
# Epoch 21/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.2491 - tp: 2155.0000 - fp: 245.0000 - tn: 2155.0000 - fn: 245.0000 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9621 - prc: 0.9610 - val_loss: 0.2607 - val_tp: 715.0000 - val_fp: 85.0000 - val_tn: 715.0000 - val_fn: 85.0000 - val_accuracy: 0.8938 - val_precision: 0.8938 - val_recall: 0.8938 - val_auc: 0.9589 - val_prc: 0.9583
# Epoch 22/100
# 75/75 [==============================] - 13s 169ms/step - loss: 0.2334 - tp: 2192.0000 - fp: 208.0000 - tn: 2192.0000 - fn: 208.0000 - accuracy: 0.9133 - precision: 0.9133 - recall: 0.9133 - auc: 0.9658 - prc: 0.9653 - val_loss: 0.2751 - val_tp: 721.0000 - val_fp: 79.0000 - val_tn: 721.0000 - val_fn: 79.0000 - val_accuracy: 0.9013 - val_precision: 0.9013 - val_recall: 0.9013 - val_auc: 0.9529 - val_prc: 0.9506
# Epoch 23/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1990 - tp: 2211.0000 - fp: 189.0000 - tn: 2211.0000 - fn: 189.0000 - accuracy: 0.9212 - precision: 0.9212 - recall: 0.9212 - auc: 0.9756 - prc: 0.9746 - val_loss: 0.2536 - val_tp: 716.0000 - val_fp: 84.0000 - val_tn: 716.0000 - val_fn: 84.0000 - val_accuracy: 0.8950 - val_precision: 0.8950 - val_recall: 0.8950 - val_auc: 0.9613 - val_prc: 0.9619
# Epoch 24/100
# 75/75 [==============================] - 13s 171ms/step - loss: 0.1923 - tp: 2225.0000 - fp: 175.0000 - tn: 2225.0000 - fn: 175.0000 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9773 - prc: 0.9764 - val_loss: 0.2655 - val_tp: 711.0000 - val_fp: 89.0000 - val_tn: 711.0000 - val_fn: 89.0000 - val_accuracy: 0.8888 - val_precision: 0.8888 - val_recall: 0.8888 - val_auc: 0.9577 - val_prc: 0.9590
# Epoch 25/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1902 - tp: 2222.0000 - fp: 178.0000 - tn: 2222.0000 - fn: 178.0000 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9778 - prc: 0.9776 - val_loss: 0.2413 - val_tp: 719.0000 - val_fp: 81.0000 - val_tn: 719.0000 - val_fn: 81.0000 - val_accuracy: 0.8988 - val_precision: 0.8988 - val_recall: 0.8988 - val_auc: 0.9677 - val_prc: 0.9689
# Epoch 26/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1728 - tp: 2234.0000 - fp: 166.0000 - tn: 2234.0000 - fn: 166.0000 - accuracy: 0.9308 - precision: 0.9308 - recall: 0.9308 - auc: 0.9818 - prc: 0.9817 - val_loss: 0.2166 - val_tp: 722.0000 - val_fp: 78.0000 - val_tn: 722.0000 - val_fn: 78.0000 - val_accuracy: 0.9025 - val_precision: 0.9025 - val_recall: 0.9025 - val_auc: 0.9723 - val_prc: 0.9718
# Epoch 27/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.1560 - tp: 2256.0000 - fp: 144.0000 - tn: 2256.0000 - fn: 144.0000 - accuracy: 0.9400 - precision: 0.9400 - recall: 0.9400 - auc: 0.9851 - prc: 0.9853 - val_loss: 0.2210 - val_tp: 736.0000 - val_fp: 64.0000 - val_tn: 736.0000 - val_fn: 64.0000 - val_accuracy: 0.9200 - val_precision: 0.9200 - val_recall: 0.9200 - val_auc: 0.9687 - val_prc: 0.9675
# Epoch 28/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1566 - tp: 2253.0000 - fp: 147.0000 - tn: 2253.0000 - fn: 147.0000 - accuracy: 0.9388 - precision: 0.9388 - recall: 0.9388 - auc: 0.9847 - prc: 0.9846 - val_loss: 0.2419 - val_tp: 717.0000 - val_fp: 83.0000 - val_tn: 717.0000 - val_fn: 83.0000 - val_accuracy: 0.8963 - val_precision: 0.8963 - val_recall: 0.8963 - val_auc: 0.9643 - val_prc: 0.9644
# Epoch 29/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1402 - tp: 2270.0000 - fp: 130.0000 - tn: 2270.0000 - fn: 130.0000 - accuracy: 0.9458 - precision: 0.9458 - recall: 0.9458 - auc: 0.9877 - prc: 0.9868 - val_loss: 0.1911 - val_tp: 736.0000 - val_fp: 64.0000 - val_tn: 736.0000 - val_fn: 64.0000 - val_accuracy: 0.9200 - val_precision: 0.9200 - val_recall: 0.9200 - val_auc: 0.9783 - val_prc: 0.9779
# Epoch 30/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1623 - tp: 2251.0000 - fp: 149.0000 - tn: 2251.0000 - fn: 149.0000 - accuracy: 0.9379 - precision: 0.9379 - recall: 0.9379 - auc: 0.9835 - prc: 0.9829 - val_loss: 0.1852 - val_tp: 738.0000 - val_fp: 62.0000 - val_tn: 738.0000 - val_fn: 62.0000 - val_accuracy: 0.9225 - val_precision: 0.9225 - val_recall: 0.9225 - val_auc: 0.9798 - val_prc: 0.9791
# Epoch 31/100
# 75/75 [==============================] - 13s 169ms/step - loss: 0.1339 - tp: 2286.0000 - fp: 114.0000 - tn: 2286.0000 - fn: 114.0000 - accuracy: 0.9525 - precision: 0.9525 - recall: 0.9525 - auc: 0.9887 - prc: 0.9889 - val_loss: 0.1847 - val_tp: 744.0000 - val_fp: 56.0000 - val_tn: 744.0000 - val_fn: 56.0000 - val_accuracy: 0.9300 - val_precision: 0.9300 - val_recall: 0.9300 - val_auc: 0.9801 - val_prc: 0.9796
# Epoch 32/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.1142 - tp: 2293.0000 - fp: 107.0000 - tn: 2293.0000 - fn: 107.0000 - accuracy: 0.9554 - precision: 0.9554 - recall: 0.9554 - auc: 0.9918 - prc: 0.9916 - val_loss: 0.1943 - val_tp: 743.0000 - val_fp: 57.0000 - val_tn: 743.0000 - val_fn: 57.0000 - val_accuracy: 0.9287 - val_precision: 0.9287 - val_recall: 0.9287 - val_auc: 0.9772 - val_prc: 0.9766
# Epoch 33/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1063 - tp: 2303.0000 - fp: 97.0000 - tn: 2303.0000 - fn: 97.0000 - accuracy: 0.9596 - precision: 0.9596 - recall: 0.9596 - auc: 0.9927 - prc: 0.9925 - val_loss: 0.1923 - val_tp: 743.0000 - val_fp: 57.0000 - val_tn: 743.0000 - val_fn: 57.0000 - val_accuracy: 0.9287 - val_precision: 0.9287 - val_recall: 0.9287 - val_auc: 0.9790 - val_prc: 0.9787
# Epoch 34/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1520 - tp: 2261.0000 - fp: 139.0000 - tn: 2261.0000 - fn: 139.0000 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9858 - prc: 0.9861 - val_loss: 0.1998 - val_tp: 744.0000 - val_fp: 56.0000 - val_tn: 744.0000 - val_fn: 56.0000 - val_accuracy: 0.9300 - val_precision: 0.9300 - val_recall: 0.9300 - val_auc: 0.9732 - val_prc: 0.9717
# Epoch 35/100
# 75/75 [==============================] - 13s 169ms/step - loss: 0.1195 - tp: 2281.0000 - fp: 119.0000 - tn: 2281.0000 - fn: 119.0000 - accuracy: 0.9504 - precision: 0.9504 - recall: 0.9504 - auc: 0.9908 - prc: 0.9904 - val_loss: 0.1691 - val_tp: 749.0000 - val_fp: 51.0000 - val_tn: 749.0000 - val_fn: 51.0000 - val_accuracy: 0.9362 - val_precision: 0.9362 - val_recall: 0.9362 - val_auc: 0.9827 - val_prc: 0.9824
# Epoch 36/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.1044 - tp: 2302.0000 - fp: 98.0000 - tn: 2302.0000 - fn: 98.0000 - accuracy: 0.9592 - precision: 0.9592 - recall: 0.9592 - auc: 0.9934 - prc: 0.9935 - val_loss: 0.1889 - val_tp: 743.0000 - val_fp: 57.0000 - val_tn: 743.0000 - val_fn: 57.0000 - val_accuracy: 0.9287 - val_precision: 0.9287 - val_recall: 0.9287 - val_auc: 0.9806 - val_prc: 0.9799
# Epoch 37/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.0878 - tp: 2322.0000 - fp: 78.0000 - tn: 2322.0000 - fn: 78.0000 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9950 - prc: 0.9948 - val_loss: 0.1790 - val_tp: 745.0000 - val_fp: 55.0000 - val_tn: 745.0000 - val_fn: 55.0000 - val_accuracy: 0.9312 - val_precision: 0.9312 - val_recall: 0.9312 - val_auc: 0.9822 - val_prc: 0.9810
# Epoch 38/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.0975 - tp: 2308.0000 - fp: 92.0000 - tn: 2308.0000 - fn: 92.0000 - accuracy: 0.9617 - precision: 0.9617 - recall: 0.9617 - auc: 0.9935 - prc: 0.9928 - val_loss: 0.1899 - val_tp: 751.0000 - val_fp: 49.0000 - val_tn: 751.0000 - val_fn: 49.0000 - val_accuracy: 0.9388 - val_precision: 0.9388 - val_recall: 0.9388 - val_auc: 0.9801 - val_prc: 0.9787
# Epoch 39/100
# 75/75 [==============================] - 13s 168ms/step - loss: 0.0795 - tp: 2338.0000 - fp: 62.0000 - tn: 2338.0000 - fn: 62.0000 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9959 - prc: 0.9960 - val_loss: 0.1786 - val_tp: 750.0000 - val_fp: 50.0000 - val_tn: 750.0000 - val_fn: 50.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9835 - val_prc: 0.9829
# Epoch 40/100
# 75/75 [==============================] - 13s 173ms/step - loss: 0.0864 - tp: 2333.0000 - fp: 67.0000 - tn: 2333.0000 - fn: 67.0000 - accuracy: 0.9721 - precision: 0.9721 - recall: 0.9721 - auc: 0.9951 - prc: 0.9953 - val_loss: 0.1835 - val_tp: 750.0000 - val_fp: 50.0000 - val_tn: 750.0000 - val_fn: 50.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9819 - val_prc: 0.9810
# Epoch 41/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.0788 - tp: 2324.0000 - fp: 76.0000 - tn: 2324.0000 - fn: 76.0000 - accuracy: 0.9683 - precision: 0.9683 - recall: 0.9683 - auc: 0.9961 - prc: 0.9959 - val_loss: 0.1638 - val_tp: 750.0000 - val_fp: 50.0000 - val_tn: 750.0000 - val_fn: 50.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9856 - val_prc: 0.9853
# Epoch 42/100
# 75/75 [==============================] - 13s 169ms/step - loss: 0.0785 - tp: 2328.0000 - fp: 72.0000 - tn: 2328.0000 - fn: 72.0000 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9959 - prc: 0.9958 - val_loss: 0.1854 - val_tp: 753.0000 - val_fp: 47.0000 - val_tn: 753.0000 - val_fn: 47.0000 - val_accuracy: 0.9413 - val_precision: 0.9413 - val_recall: 0.9413 - val_auc: 0.9822 - val_prc: 0.9805
# Epoch 43/100
# 75/75 [==============================] - 13s 167ms/step - loss: 0.0646 - tp: 2347.0000 - fp: 53.0000 - tn: 2347.0000 - fn: 53.0000 - accuracy: 0.9779 - precision: 0.9779 - recall: 0.9779 - auc: 0.9970 - prc: 0.9969 - val_loss: 0.1714 - val_tp: 755.0000 - val_fp: 45.0000 - val_tn: 755.0000 - val_fn: 45.0000 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9837 - val_prc: 0.9822
# Epoch 44/100
# 75/75 [==============================] - 13s 169ms/step - loss: 0.0615 - tp: 2346.0000 - fp: 54.0000 - tn: 2346.0000 - fn: 54.0000 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9976 - prc: 0.9977 - val_loss: 0.1759 - val_tp: 747.0000 - val_fp: 53.0000 - val_tn: 747.0000 - val_fn: 53.0000 - val_accuracy: 0.9337 - val_precision: 0.9337 - val_recall: 0.9337 - val_auc: 0.9836 - val_prc: 0.9835
# Epoch 45/100
# 75/75 [==============================] - 13s 171ms/step - loss: 0.0651 - tp: 2344.0000 - fp: 56.0000 - tn: 2344.0000 - fn: 56.0000 - accuracy: 0.9767 - precision: 0.9767 - recall: 0.9767 - auc: 0.9968 - prc: 0.9965 - val_loss: 0.2526 - val_tp: 741.0000 - val_fp: 59.0000 - val_tn: 741.0000 - val_fn: 59.0000 - val_accuracy: 0.9262 - val_precision: 0.9262 - val_recall: 0.9262 - val_auc: 0.9745 - val_prc: 0.9711
# Epoch 46/100
# 75/75 [==============================] - 14s 181ms/step - loss: 0.0590 - tp: 2350.0000 - fp: 50.0000 - tn: 2350.0000 - fn: 50.0000 - accuracy: 0.9792 - precision: 0.9792 - recall: 0.9792 - auc: 0.9978 - prc: 0.9979 - val_loss: 0.2040 - val_tp: 751.0000 - val_fp: 49.0000 - val_tn: 751.0000 - val_fn: 49.0000 - val_accuracy: 0.9388 - val_precision: 0.9388 - val_recall: 0.9388 - val_auc: 0.9801 - val_prc: 0.9769
# Epoch 47/100
# 75/75 [==============================] - 13s 173ms/step - loss: 0.0582 - tp: 2352.0000 - fp: 48.0000 - tn: 2352.0000 - fn: 48.0000 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9978 - prc: 0.9979 - val_loss: 0.1881 - val_tp: 752.0000 - val_fp: 48.0000 - val_tn: 752.0000 - val_fn: 48.0000 - val_accuracy: 0.9400 - val_precision: 0.9400 - val_recall: 0.9400 - val_auc: 0.9821 - val_prc: 0.9802
# Epoch 48/100
# 75/75 [==============================] - 13s 174ms/step - loss: 0.0455 - tp: 2362.0000 - fp: 38.0000 - tn: 2362.0000 - fn: 38.0000 - accuracy: 0.9842 - precision: 0.9842 - recall: 0.9842 - auc: 0.9983 - prc: 0.9982 - val_loss: 0.1832 - val_tp: 750.0000 - val_fp: 50.0000 - val_tn: 750.0000 - val_fn: 50.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9814 - val_prc: 0.9794
# Epoch 49/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.0388 - tp: 2368.0000 - fp: 32.0000 - tn: 2368.0000 - fn: 32.0000 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9992 - prc: 0.9992 - val_loss: 0.1859 - val_tp: 751.0000 - val_fp: 49.0000 - val_tn: 751.0000 - val_fn: 49.0000 - val_accuracy: 0.9388 - val_precision: 0.9388 - val_recall: 0.9388 - val_auc: 0.9852 - val_prc: 0.9846
# Epoch 50/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.0343 - tp: 2374.0000 - fp: 26.0000 - tn: 2374.0000 - fn: 26.0000 - accuracy: 0.9892 - precision: 0.9892 - recall: 0.9892 - auc: 0.9993 - prc: 0.9994 - val_loss: 0.1969 - val_tp: 750.0000 - val_fp: 50.0000 - val_tn: 750.0000 - val_fn: 50.0000 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9816 - val_prc: 0.9789
# Epoch 51/100
# 75/75 [==============================] - 13s 170ms/step - loss: 0.0949 - tp: 2323.0000 - fp: 77.0000 - tn: 2323.0000 - fn: 77.0000 - accuracy: 0.9679 - precision: 0.9679 - recall: 0.9679 - auc: 0.9936 - prc: 0.9929 - val_loss: 0.2682 - val_tp: 730.0000 - val_fp: 70.0000 - val_tn: 730.0000 - val_fn: 70.0000 - val_accuracy: 0.9125 - val_precision: 0.9125 - val_recall: 0.9125 - val_auc: 0.9655 - val_prc: 0.9627
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping

# %%
plot_metrics(history)

# %% [markdown]
# We see that the best epoch is the 11th, the training ended 10 epochs later.

# %% [markdown]
# * * #### Confusion Matrix

# %%
train_predictions_baseline = model.predict(X_train)
test_predictions_baseline = model.predict(X_test)

# %%
baseline_results = model.evaluate(X_test, y_test, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
print()

plot_cm(y_test, test_predictions_baseline)
# Out:
# loss :  0.223745197057724
# tp :  744.0
# fp :  56.0
# tn :  744.0
# fn :  56.0
# accuracy :  0.9300000071525574
# precision :  0.9300000071525574
# recall :  0.9300000071525574
# auc :  0.9724069833755493
# prc :  0.9683678150177002

# %%
(12/579)
# Out:
# 0.02072538860103627

# %% [markdown]
# Big improvement on the positive class (__Ship__) prediction

# %% [markdown]
# * * #### ROC Curve

# %%
plot_roc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# * *  #### AUPRC (precision-recall curve)

# %%
plot_prc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_prc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# The improvement is clearly present in this chart, we can see that the model can keep a high precision while having a high recall.
#
# This chart is very important. Knowing that the prediction rely on the probability of each class returned by the softmax function. This chart can indicate the prefered tradeoff regarding to our problematic. With it, we can modify the theshold decision function.
#
# For exemple, if we want to detect ships present in protected areas. We probably don't want to miss any ship, so we will prefer the recall against precision. For instance, a model which has only 30% precision as long as it has 99% recall could be a perfect model for this type of situation.

# %% [markdown]
# # Errors Exploration

# %% [markdown]
# The model has excellent results.
#
# To understand the errors that it made. We will explore the images misclassified

# %%
test_predictions_baseline
# Out:
# array([[4.1201198e-05, 9.9995875e-01],
#        [1.0000000e+00, 8.8205979e-15],
#        [6.8426730e-06, 9.9999321e-01],
#        ...,
#        [9.9980718e-01, 1.9286053e-04],
#        [1.0000000e+00, 7.7453519e-14],
#        [9.9999988e-01, 6.1291068e-08]], dtype=float32)

# %%
df = pd.DataFrame(test_predictions_baseline, columns=["no_ship",'ship'])
df['label'] = y_test[:, 1]
df
# Out:
#       no_ship          ship  label
# 0    0.000041  9.999588e-01    1.0
# 1    1.000000  8.820598e-15    0.0
# 2    0.000007  9.999932e-01    1.0
# 3    0.572598  4.274020e-01    0.0
# 4    1.000000  3.952862e-14    0.0
# ..        ...           ...    ...
# 795  0.276134  7.238662e-01    0.0
# 796  0.000042  9.999579e-01    1.0
# 797  0.999807  1.928605e-04    0.0
# 798  1.000000  7.745352e-14    0.0
# 799  1.000000  6.129107e-08    0.0
#
# [800 rows x 3 columns]

# %%
# Print the images missclassified as not ship
df_erros = df[(df.no_ship > df.ship) & (df.label == 1)]

# %%
(X_test[df_erros.index.values])
# Out:
# (6, 80, 80, 3)

# %%
show_examples(classes= {0:'No_ship',1:'Ship'},
              images= X_test[df_erros.index.values], #X
              labels= y_test[df_erros.index.values], #y
              set_name= 'Erros',
             nbr_images=6)

# %% [markdown]
# We clearly see that these images are in fact ships that where misslabeled as not ships.
#
# So the 6 remaining errors are not errors.
#
# We will relabel them

# %%
# Print the images missclassified as not ship
df_erros2 = df[(df.no_ship < df.ship) & (df.label == 0)]

# %%
show_examples(classes= {0:'No_ship',1:'Ship'},
              images= X_test[df_erros2.index.values], #X
              labels= y_test[df_erros2.index.values], #y
              set_name= 'Erros',
             nbr_images=12)

# %% [markdown]
# As we noticed in the EDA, the dikes and bridges could lead the model to erros.
#
# It encompasses 4/12 of the errors

# %% [markdown]
# # Save Model

# %%
import time
ts = time.time()
ts = str(int(ts))

model.save('../models/CNN_'+ts+'.h5')
